# %%
#importing numpy for linear algebra and pandas for data processing
import numpy as np 
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Informations

# %%
#importing the dataset
netflix = pd.read_csv("./data/netflix_titles_2021.csv")

# %%
# checking first 5 rows ( overview )
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# displaying Dataframe info
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# So the dataset has __8807 entries__ and __12 columns__ ( 1 integer and the rest is objects )

# %%
# checking for unique values
netflix.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
# checking duplicates 
netflix.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - So no duplicated rows ( and no duplicate shows )
# - 2 Types of shows
# - 17 Ratings

# %%
# description of the data
netflix.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ### Handling Missing Values

# %%
# checking missing values of each col
miss = netflix.isna().sum()
miss
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# calc the % of missing values for each col
percent_miss = netflix.isnull().mean() * 100
percent_miss
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
# only displaying what has missing values
percent_miss[percent_miss > 0]
# Out:
# director      29.908028
# cast           9.367549
# country        9.435676
# date_added     0.113546
# rating         0.045418
# duration       0.034064
# dtype: float64

# %%
sns.heatmap(netflix.isnull())
# Out:
# <Axes: >

# %% [markdown]
# - director, cast and country columns contain most null values
# - date_added and duration have a couple
#
# So we're gonna delete director and cast null rows.

# %%
netflix_copy = netflix.copy().dropna(how="any", subset=["director","cast"])
netflix_copy.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
netflix_copy.fillna({"country":"unkown",'date_added':'unkown', 'rating':'unkown', 'duration':'unkown'},inplace=True)
netflix_copy.isnull().mean()
# Out:
# show_id         0.0
# type            0.0
# title           0.0
# director        0.0
# cast            0.0
# country         0.0
# date_added      0.0
# release_year    0.0
# rating          0.0
# duration        0.0
# listed_in       0.0
# description     0.0
# dtype: float64

# %% [markdown]
# Nice we got rid of null values

# %%
netflix_copy.shape
# Out:
# (5336, 12)

# %% [markdown]
# So now we have 5700 entries left

# %% [markdown]
# ### EDA questions

# %% [markdown]
# ##### 1. What is the proportion of Movies vs TV Shows on Netflix?

# %%
netflix_copy.type.value_counts().to_frame("Amount")
# Out:
#          Amount
# type
# Movie      5189
# TV Show     147

# %%
sns.countplot(x="type",data=netflix_copy)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# *Observation* : Netflix is primarily streaming Movies.

# %% [markdown]
# ##### 2. How has the balance between Movies and TV Shows changed over time?

# %%
netflix_copy["date_added"] = pd.to_datetime(netflix_copy["date_added"], errors="coerce")
netflix_copy["year_added"] = netflix_copy["date_added"].dt.year

type_proportions = netflix_copy.groupby(["year_added", "type"]).size().reset_index(name="count")
type_proportions["percent"] = type_proportions.groupby("year_added")["count"].transform(lambda x: x/x.sum() * 100)

sns.lineplot(data=type_proportions, x="year_added", y="percent", hue="type", marker="o")
# Out:
# <Axes: xlabel='year_added', ylabel='percent'>

# %% [markdown]
# *Observation* :
# - No TV shows in early netflix years ( 2008 to 2013 ).
# - Appearance of TV Shows starting 2013 with a slight dip in movies
# - Movies still dominating even years later
# - TV shows slowly but increasingly getting attraction starting 2018

# %% [markdown]
# ##### 3. Which countries contribute the most content to Netflix?

# %%
top_countries = (
    netflix_copy["country"]
    .value_counts(normalize=True)
    .sort_values(ascending=False)
    .head(10)
    .reset_index(name="count")
)

top_countries["count"] *= 100

plt.figure(figsize=(12,6))
sns.barplot(data=top_countries, x="country", y="count")
plt.title("Top 10 Countries Contributing to Netflix Content")
plt.ylabel("% of Titles")
plt.xlabel("Country")
# Out:
# Text(0.5, 0, 'Country')

# %% [markdown]
# *Observation* : The majority of netflix content is from US, India and UK
